# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/18_While_Loop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
While loop
Excelente para loops dependentes de uma condição
Publicar um produto com uma comissão de 10% se for acima de $20,00
'''

valor = int(input('Digite o valor do seu produto: '))
#print(valor)
while valor > 21:
  valor = (valor * 0.10) + valor
  print(f'O valor final do seu produto é {valor}')
  break
# Out:
# Digite o valor do seu produto: 21
# O valor final do seu produto é 23.1
