# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/TestandoColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# experimentando plataforma google colab

nome = 'Arthur'
idade = 45
mensagem = 'Bom dia'
altura = 1.92
professor = True

print(type(nome))
print(type(idade))
print(type(mensagem))
print(type(altura))
print(type(professor))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input('Digite seu nome: ')
idade = input('Digite sua idade: ')
print('Olá ' + nome + ' você tem', idade )
# Out:
# Digite seu nome: Arthur
# Digite sua idade: 45
# Olá Arthur você tem 45
