# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/09_Polimorfismo_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Cachorro():
  def emitir_som(self):
    print("Au Au")

class Gato():
  def emitir_som(self):
    print("miau miau")

animais = [Cachorro(), Gato()]

for a in animais:
  a.emitir_som()
# Out:
# Au Au
# miau miau
