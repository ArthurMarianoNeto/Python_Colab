# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/17_Operador_Ternario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ternary Operator (Operador Ternário)
# Checar se pessoa tem idade para votar
idade = 13
'''
if idade >= 16:
 resultado = print('Voto permitido')
else:
  resultado = print('Voto não permitido')
'''
resultado = 'Voto permitido' if idade >= 16 else 'Voto não permitido'
print(resultado)
# Out:
# Voto não permitido
