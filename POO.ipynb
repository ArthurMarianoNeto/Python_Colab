# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Casa:
    def __init__(self,cor, quartos, banheiros):
      self.cor = cor
      self.quartos = quartos
      self.banheiros = banheiros

    def mostrar_cor(self):
      print(f'A cor da casa {self.cor}')

    def mostrar_quartos(self):
      print(f'A casa tem {self.quartos} quartos')

    def mostrar_bancheiros(self):
      print(f'A casa tem {self.banheiros} banheiros')

    def adicionar_quartos(self):
      self.quartos += 1
      print(f'Esta casa tem {self.quartos} quartos')

    def pintar_casa(self, nova_cor):
      print(f'Pintando a casa de {self.cor} para {nova_cor}')


casa1 = Casa('Azul', 4, 3)
casa2 = Casa('Vermelha', 6, 9)

print('\ncasa1.cor:')
casa1.mostrar_cor()
casa1.mostrar_quartos()
casa1.mostrar_bancheiros()
casa1.adicionar_quartos()
casa1.pintar_casa('Verde')

print('\ncasa1.cor:')
casa2.mostrar_cor()
casa2.mostrar_quartos()
casa2.mostrar_bancheiros()
# Out:
# casa1.cor:
# A cor da casa Azul
# A casa tem 4 quartos
# A casa tem 3 banheiros
# Esta casa tem 5 quartos
# Pintando a casa de Azul para Verde
#
# casa1.cor:
# A cor da casa Vermelha
# A casa tem 6 quartos
# A casa tem 9 banheiros
