# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarianoNeto/Python_Colab/blob/main/Nested_Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# classes aninhadas
class Computador:
    def __init__(self, modelo, gpu_nome, gpu_memoria, cpu_nome, cpu_cores, cpu_clock):
      self.modelo = modelo
      self.gpu_nome = gpu_nome
      self.gpu = self.GPU(gpu_nome, gpu_memoria)
      self.cpu = self.CPU(cpu_nome, cpu_cores, cpu_clock)

    def mostrar_configuracao(self):
      print(f'Computador: {self.modelo}')
      self.gpu.mostrar_gpu()
      self.cpu.mostrar_cpu()

    # Nested Class GPU
    class GPU:
      def __init__(self, nome, memoria_gb):
        self.nome = nome
        self.memoria_gb = memoria_gb

      def mostrar_gpu(self):
        print(f'GPU {self.nome} - {self.memoria_gb}')

    # Nested Class CPU
    class CPU:
      def __init__(self, nome, cores, clock_ghz):
        self.nome = nome
        self.cores = cores
        self.clock_ghz = clock_ghz

      def mostrar_cpu(self):
        print(f'CPU-Nome: {self.nome} - CPU-Cores: {self.cores} - GHz: {self.clock_ghz}')

# Utilização
pc1 = Computador('Dell XPS', 'NVIDIA RTX 4090', 24, 'Intel Core i7', 8, 4.6)
pc1.mostrar_configuracao()
#pc1.gpu.mostrar_gpu()
# Out:
# Computador: Dell XPS
# GPU NVIDIA RTX 4090 - 24
# CPU-Nome: Intel Core i7 - CPU-Cores: 8 - GHz: 4.6
