# %%
'''
While Loop
Excelente para loops dependentes de uma condição
Criar uma promoção para um produto no valor de $100,00
'''
valor = 100
dia = 0
while valor > 20:
  dia += 1
  print(f'No dia {dia} o produto será vendido poelo o valor de ${valor},00')
  #print(valor)
  valor -= 5
# Out:
# No dia 1 o produto será vendido poelo o valor de $100,00
# No dia 2 o produto será vendido poelo o valor de $95,00
# No dia 3 o produto será vendido poelo o valor de $90,00
# No dia 4 o produto será vendido poelo o valor de $85,00
# No dia 5 o produto será vendido poelo o valor de $80,00
# No dia 6 o produto será vendido poelo o valor de $75,00
# No dia 7 o produto será vendido poelo o valor de $70,00
# No dia 8 o produto será vendido poelo o valor de $65,00
# No dia 9 o produto será vendido poelo o valor de $60,00
# No dia 10 o produto será vendido poelo o valor de $55,00
# No dia 11 o produto será vendido poelo o valor de $50,00
# No dia 12 o produto será vendido poelo o valor de $45,00
# No dia 13 o produto será vendido poelo o valor de $40,00
# No dia 14 o produto será vendido poelo o valor de $35,00
# No dia 15 o produto será vendido poelo o valor de $30,00
# No dia 16 o produto será vendido poelo o valor de $25,00
